# %% [markdown]
#      1 #include <iostream>
#      2  #include <iomanip>
#      3
#      4  using namespace std;
#      5
#      6  int main()
#      7  {
#      8
#      9      double celsius, fahrenheit;
#     10
#     11
#     12      char choice;
#     13      bool exit = false;
#     14
#     15      do
#     16      {
#     17
#     18          cout << "Choose the conversion type:" << endl;
#     19          cout << "1. Celsius to Fahrenheit" << endl;
#     20          cout << "2. Fahrenheit to Celsius" << endl;
#     21          cout << "Enter your choice (1 or 2), or any other key to exit: ";
#     22          cin >> choice;
#     23
#     24          switch (choice)
#     25          {
#     26          case '1':
#     27
#     28              cout << "Enter Temperature in Celsius: ";
#     29
#     30              cin >> celsius;
#     31
#     32              fahrenheit = (celsius * 9.0 / 5.0) + 32;
#     33
#     34              cout << "Temperature: " << fixed << setprecision(2) << fahrenheit << "°F" << endl;
#     35              break;
#     36
#     37          case '2':
#     38
#     39              cout << "Enter Temperature in Fahrenheit: ";
#     40
#     41              cin >> fahrenheit;
#     42
#     43              celsius = (fahrenheit - 32) * 5.0 / 9.0;
#     44
#     45              cout << "Temperature: " << fixed << setprecision(2) << celsius << "°C" << endl;
#     46              break;
#     47
#     48          default:
#     49              cout << "Exiting the program. Goodbye!" << endl;
#     50              exit = true;
#     51              break;
#     52          }
#     53
#     54          cout << endl;
#     55
#     56      } while (!exit);
#     57
#     58      return 0;
#     59  }
#     60
#     61
#     62
#     63
